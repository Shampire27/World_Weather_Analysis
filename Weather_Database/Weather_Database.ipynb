# %%
# Import the dependencies.
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Import the dependencies.
import pandas as pd
from citipy import citipy

# %%
# Get the nearest city using the citipy module.

cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
    try:
    # If the city is unique, then we will add it to the cities list.
        if city not in cities:
            cities.append(city)
    except():
        print("General Error... skipping.")   
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d95e6d8d2d73de514c93bb895f30a8ad

# %%
# Perform an API call with the OpenWeatherMap.

# Retrieve the following information from the API call:

## Latitude and longitude
## Maximum temperature
## Percent humidity
## Percent cloudiness
## Wind speed
## Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        # city_weather_main=city_weather["weather"][0]["main"]   
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          # "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | sines
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | okitipupa
# Processing Record 6 of Set 1 | muborak
# Processing Record 7 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | lerwick
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | tecolutla
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | cairns
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | bundaberg
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | hambantota
# Processing Record 27 of Set 1 | jalu
# Processing Record 28 of Set 1 | anadyr
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | fare
# Processing Record 31 of Set 1 | udachnyy
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | touros
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | haileybury
# Processing Record 37 of Set 1 | namibe
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | caravelas
# Processing Record 40 of Set 1 | khor
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | lima
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | seaford
# Processing Record 46 of Set 1 | grindavik
# Processing Record 47 of Set 1 | itarema
# Processing Record 48 of Set 1 | atar
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | barra da estiva
# Processing Record 6 of Set 2 | coihaique
# Processing Record 7 of Set 2 | koslan
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | seoul
# Processing Record 10 of Set 2 | kamaishi
# Processing Record 11 of Set 2 | kiruna
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | sao joao da barra
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | andros
# Processing Record 18 of Set 2 | sri aman
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | srednekolymsk
# Processing Record 22 of Set 2 | hualmay
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | isangel
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | mondlo
# Processing Record 27 of Set 2 | oppdal
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | sangar
# Processing Record 31 of Set 2 | miles city
# Processing Record 32 of Set 2 | bodden town
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | aykhal
# Processing Record 37 of Set 2 | sarangani
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | san patricio
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | khorramabad
# Processing Record 47 of Set 2 | along
# Processing Record 48 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 2 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | takoradi
# Processing Record 3 of Set 3 | marsh harbour
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | bubaque
# Processing Record 6 of Set 3 | pitimbu
# Processing Record 7 of Set 3 | bucak
# Processing Record 8 of Set 3 | beloha
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | vestmanna
# Processing Record 11 of Set 3 | kedrovyy
# Processing Record 12 of Set 3 | margate
# Processing Record 13 of Set 3 | bowen
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | rosario
# Processing Record 20 of Set 3 | codrington
# Processing Record 21 of Set 3 | tias
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | beberibe
# Processing Record 25 of Set 3 | rethimnon
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | charters towers
# Processing Record 28 of Set 3 | half moon bay
# Processing Record 29 of Set 3 | bonavista
# Processing Record 30 of Set 3 | krasnovishersk
# Processing Record 31 of Set 3 | paramonga
# Processing Record 32 of Set 3 | vanimo
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | trujillo
# Processing Record 35 of Set 3 | flinders
# Processing Record 36 of Set 3 | marienburg
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | beni mazar
# Processing Record 42 of Set 3 | batagay-alyta
# Processing Record 43 of Set 3 | mayo
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | bara
# Processing Record 46 of Set 3 | la asuncion
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | barsuki
# Processing Record 49 of Set 3 | saint-augustin
# Processing Record 50 of Set 3 | iberia
# Processing Record 1 of Set 4 | oistins
# Processing Record 2 of Set 4 | hobart
# Processing Record 3 of Set 4 | les cayes
# Processing Record 4 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 5 of Set 4 | los llanos de aridane
# Processing Record 6 of Set 4 | lodwar
# Processing Record 7 of Set 4 | maceio
# Processing Record 8 of Set 4 | gashua
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | cherskiy
# Processing Record 11 of Set 4 | gat
# Processing Record 12 of Set 4 | tual
# Processing Record 13 of Set 4 | mana
# Processing Record 14 of Set 4 | marsa matruh
# Processing Record 15 of Set 4 | la palma
# Processing Record 16 of Set 4 | el chol
# Processing Record 17 of Set 4 | ostrovnoy
# Processing Record 18 of Set 4 | strathroy
# Processing Record 19 of Set 4 | sayhat
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | oga
# Processing Record 23 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 4 | tongzhou
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | vao
# Processing Record 27 of Set 4 | kahta
# Processing Record 28 of Set 4 | sioux lookout
# Processing Record 29 of Set 4 | vysokogornyy
# Processing Record 30 of Set 4 | bithur
# Processing Record 31 of Set 4 | opelousas
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 4 | ust-kulom
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | palmer
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | yinchuan
# Processing Record 40 of Set 4 | fort nelson
# Processing Record 41 of Set 4 | deputatskiy
# Processing Record 42 of Set 4 | klichka
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | egvekinot
# Processing Record 47 of Set 4 | tabou
# Processing Record 48 of Set 4 | kamloops
# Processing Record 49 of Set 4 | misratah
# Processing Record 50 of Set 4 | maracana
# Processing Record 1 of Set 5 | muzaffarabad
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | dingle
# Processing Record 4 of Set 5 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 5 | flic en flac
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | teguise
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | sitka
# Processing Record 10 of Set 5 | konevo
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | buraydah
# Processing Record 13 of Set 5 | vila franca do campo
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | san juan
# Processing Record 16 of Set 5 | labuhan
# Processing Record 17 of Set 5 | acapulco
# Processing Record 18 of Set 5 | hofn
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | mayor pablo lagerenza
# Processing Record 21 of Set 5 | port-gentil
# Processing Record 22 of Set 5 | fundao
# Processing Record 23 of Set 5 | jamiltepec
# Processing Record 24 of Set 5 | ponta delgada
# Processing Record 25 of Set 5 | saint-georges
# Processing Record 26 of Set 5 | epinal
# Processing Record 27 of Set 5 | viedma
# Processing Record 28 of Set 5 | zhigansk
# Processing Record 29 of Set 5 | rio cuarto
# Processing Record 30 of Set 5 | heinola
# Processing Record 31 of Set 5 | groningen
# Processing Record 32 of Set 5 | qatana
# Processing Record 33 of Set 5 | pueblo bello
# Processing Record 34 of Set 5 | omsukchan
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | alofi
# Processing Record 37 of Set 5 | nouakchott
# Processing Record 38 of Set 5 | maldaresti
# Processing Record 39 of Set 5 | kimbe
# Processing Record 40 of Set 5 | high level
# Processing Record 41 of Set 5 | kununurra
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | ocampo
# Processing Record 45 of Set 5 | outjo
# Processing Record 46 of Set 5 | beira
# Processing Record 47 of Set 5 | perene
# Processing Record 48 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 5 | paptalaya
# Processing Record 50 of Set 5 | vilhena
# Processing Record 1 of Set 6 | dicabisagan
# Processing Record 2 of Set 6 | salym
# Processing Record 3 of Set 6 | harper
# Processing Record 4 of Set 6 | fairbanks
# Processing Record 5 of Set 6 | bambanglipuro
# Processing Record 6 of Set 6 | bonthe
# Processing Record 7 of Set 6 | cap malheureux
# Processing Record 8 of Set 6 | qasigiannguit
# Processing Record 9 of Set 6 | soledade
# Processing Record 10 of Set 6 | mgandu
# Processing Record 11 of Set 6 | hami
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | kendari
# Processing Record 14 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 15 of Set 6 | lebu
# Processing Record 16 of Set 6 | katsuura
# Processing Record 17 of Set 6 | cuiaba
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | pacific grove
# Processing Record 20 of Set 6 | urdoma
# Processing Record 21 of Set 6 | ghugus
# Processing Record 22 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 6 | bandar-e anzali
# Processing Record 24 of Set 6 | kyzyl-suu
# Processing Record 25 of Set 6 | kishi
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | aswan
# Processing Record 28 of Set 6 | yerbogachen
# Processing Record 29 of Set 6 | wewak
# Processing Record 30 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 6 | soto la marina
# Processing Record 32 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 6 | portland
# Processing Record 34 of Set 6 | clyde river
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | tromso
# Processing Record 37 of Set 6 | norman wells
# Processing Record 38 of Set 6 | salinas
# Processing Record 39 of Set 6 | osorio
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | sovetskiy
# Processing Record 42 of Set 6 | uray
# Processing Record 43 of Set 6 | ixtapa
# Processing Record 44 of Set 6 | springfield
# Processing Record 45 of Set 6 | port hardy
# Processing Record 46 of Set 6 | sur
# Processing Record 47 of Set 6 | upernavik
# Processing Record 48 of Set 6 | kanniyakumari
# Processing Record 49 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 6 | phan thiet
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | richards bay
# Processing Record 3 of Set 7 | peniche
# Processing Record 4 of Set 7 | san ramon
# Processing Record 5 of Set 7 | stornoway
# Processing Record 6 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 7 of Set 7 | dori
# Processing Record 8 of Set 7 | saskylakh
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | esna
# Processing Record 12 of Set 7 | tamandare
# Processing Record 13 of Set 7 | kavieng
# Processing Record 14 of Set 7 | tikhvin
# Processing Record 15 of Set 7 | makakilo city
# Processing Record 16 of Set 7 | yokadouma
# Processing Record 17 of Set 7 | minab
# Processing Record 18 of Set 7 | riyadh
# Processing Record 19 of Set 7 | nouadhibou
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | belmonte
# Processing Record 22 of Set 7 | bagan
# Processing Record 23 of Set 7 | korla
# Processing Record 24 of Set 7 | hobyo
# Processing Record 25 of Set 7 | dudinka
# Processing Record 26 of Set 7 | sorland
# Processing Record 27 of Set 7 | atasu
# Processing Record 28 of Set 7 | virginia beach
# Processing Record 29 of Set 7 | ordzhonikidze
# Processing Record 30 of Set 7 | alcacer do sal
# Processing Record 31 of Set 7 | russell
# Processing Record 32 of Set 7 | gambela
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | beroroha
# Processing Record 35 of Set 7 | geraldton
# Processing Record 36 of Set 7 | providencia
# Processing Record 37 of Set 7 | canandaigua
# Processing Record 38 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 7 | karakol
# Processing Record 40 of Set 7 | muswellbrook
# Processing Record 41 of Set 7 | zhumadian
# Processing Record 42 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 7 | pandan
# Processing Record 44 of Set 7 | saint-jean-port-joli
# Processing Record 45 of Set 7 | baiao
# Processing Record 46 of Set 7 | valdivia
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | wuda
# Processing Record 49 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 7 | planaltina
# Processing Record 1 of Set 8 | frankfort
# Processing Record 2 of Set 8 | jizan
# Processing Record 3 of Set 8 | bereda
# Processing Record 4 of Set 8 | biak
# Processing Record 5 of Set 8 | baherden
# Processing Record 6 of Set 8 | naryan-mar
# Processing Record 7 of Set 8 | ornskoldsvik
# Processing Record 8 of Set 8 | yazoo city
# Processing Record 9 of Set 8 | chisindia
# Processing Record 10 of Set 8 | hede
# Processing Record 11 of Set 8 | baghpat
# Processing Record 12 of Set 8 | provideniya
# Processing Record 13 of Set 8 | lewiston
# Processing Record 14 of Set 8 | ushtobe
# Processing Record 15 of Set 8 | opuwo
# Processing Record 16 of Set 8 | conceicao do araguaia
# Processing Record 17 of Set 8 | bealanana
# Processing Record 18 of Set 8 | wampusirpi
# City not found. Skipping...
# Processing Record 19 of Set 8 | ekuvukeni
# Processing Record 20 of Set 8 | boa vista
# Processing Record 21 of Set 8 | inirida
# Processing Record 22 of Set 8 | hennenman
# Processing Record 23 of Set 8 | zaria
# Processing Record 24 of Set 8 | doctor phillips
# Processing Record 25 of Set 8 | hearst
# Processing Record 26 of Set 8 | klaksvik
# Processing Record 27 of Set 8 | tazovskiy
# Processing Record 28 of Set 8 | shiraz
# Processing Record 29 of Set 8 | statesboro
# Processing Record 30 of Set 8 | teya
# Processing Record 31 of Set 8 | carnarvon
# Processing Record 32 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 8 | quatre cocos
# Processing Record 34 of Set 8 | jorhat
# Processing Record 35 of Set 8 | leningradskiy
# Processing Record 36 of Set 8 | varzea alegre
# Processing Record 37 of Set 8 | abay
# Processing Record 38 of Set 8 | husavik
# Processing Record 39 of Set 8 | siavonga
# Processing Record 40 of Set 8 | airai
# Processing Record 41 of Set 8 | oktyabrskiy
# Processing Record 42 of Set 8 | evensk
# Processing Record 43 of Set 8 | manjacaze
# Processing Record 44 of Set 8 | asyut
# Processing Record 45 of Set 8 | malayal
# Processing Record 46 of Set 8 | xunchang
# Processing Record 47 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 48 of Set 8 | seydisehir
# Processing Record 49 of Set 8 | kiunga
# Processing Record 50 of Set 8 | yar-sale
# Processing Record 1 of Set 9 | mackay
# Processing Record 2 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 9 | palimbang
# Processing Record 4 of Set 9 | oranjestad
# Processing Record 5 of Set 9 | the valley
# Processing Record 6 of Set 9 | belaya gora
# Processing Record 7 of Set 9 | yangambi
# Processing Record 8 of Set 9 | simbahan
# Processing Record 9 of Set 9 | qandala
# Processing Record 10 of Set 9 | aden
# Processing Record 11 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 9 | sibolga
# Processing Record 13 of Set 9 | verkhoyansk
# Processing Record 14 of Set 9 | adrar
# Processing Record 15 of Set 9 | barra do garcas
# Processing Record 16 of Set 9 | rawson
# Processing Record 17 of Set 9 | port hawkesbury
# Processing Record 18 of Set 9 | sergach
# Processing Record 19 of Set 9 | taoudenni
# Processing Record 20 of Set 9 | pitsunda
# Processing Record 21 of Set 9 | yershov
# Processing Record 22 of Set 9 | bac lieu
# Processing Record 23 of Set 9 | flin flon
# Processing Record 24 of Set 9 | cayenne
# Processing Record 25 of Set 9 | luneville
# Processing Record 26 of Set 9 | platteville
# Processing Record 27 of Set 9 | atherton
# Processing Record 28 of Set 9 | kaitangata
# Processing Record 29 of Set 9 | tigil
# Processing Record 30 of Set 9 | nelson bay
# Processing Record 31 of Set 9 | san-pedro
# Processing Record 32 of Set 9 | makurdi
# Processing Record 33 of Set 9 | carman
# Processing Record 34 of Set 9 | touba
# Processing Record 35 of Set 9 | medicine hat
# Processing Record 36 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 9 | japura
# Processing Record 38 of Set 9 | macomb
# Processing Record 39 of Set 9 | bilibino
# Processing Record 40 of Set 9 | llanes
# Processing Record 41 of Set 9 | scarborough
# Processing Record 42 of Set 9 | dzilam gonzalez
# Processing Record 43 of Set 9 | saldanha
# Processing Record 44 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 9 | popondetta
# Processing Record 46 of Set 9 | curuca
# Processing Record 47 of Set 9 | port macquarie
# Processing Record 48 of Set 9 | luderitz
# Processing Record 49 of Set 9 | bima
# Processing Record 50 of Set 9 | elk city
# Processing Record 1 of Set 10 | pangody
# Processing Record 2 of Set 10 | stephenville
# Processing Record 3 of Set 10 | elliot lake
# Processing Record 4 of Set 10 | celestun
# Processing Record 5 of Set 10 | tingo maria
# Processing Record 6 of Set 10 | igunga
# Processing Record 7 of Set 10 | brownfield
# Processing Record 8 of Set 10 | ulladulla
# Processing Record 9 of Set 10 | ayni
# Processing Record 10 of Set 10 | tsevie
# Processing Record 11 of Set 10 | hit
# Processing Record 12 of Set 10 | wamba
# Processing Record 13 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 10 | okha
# Processing Record 15 of Set 10 | ambon
# Processing Record 16 of Set 10 | lafayette
# Processing Record 17 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 18 of Set 10 | dawei
# Processing Record 19 of Set 10 | gisborne
# Processing Record 20 of Set 10 | la seyne-sur-mer
# Processing Record 21 of Set 10 | kirakira
# Processing Record 22 of Set 10 | sao filipe
# Processing Record 23 of Set 10 | cabinda
# Processing Record 24 of Set 10 | houma
# Processing Record 25 of Set 10 | vallenar
# Processing Record 26 of Set 10 | krasnoselkup
# Processing Record 27 of Set 10 | mahon
# Processing Record 28 of Set 10 | chara
# Processing Record 29 of Set 10 | stony plain
# Processing Record 30 of Set 10 | kenai
# Processing Record 31 of Set 10 | muisne
# Processing Record 32 of Set 10 | namatanai
# Processing Record 33 of Set 10 | tezu
# Processing Record 34 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 35 of Set 10 | necochea
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | faya
# Processing Record 38 of Set 10 | tortoli
# Processing Record 39 of Set 10 | turayf
# Processing Record 40 of Set 10 | asosa
# Processing Record 41 of Set 10 | port hedland
# Processing Record 42 of Set 10 | grand-santi
# Processing Record 43 of Set 10 | sumbe
# Processing Record 44 of Set 10 | southbridge
# Processing Record 45 of Set 10 | rovaniemi
# Processing Record 46 of Set 10 | colmar
# Processing Record 47 of Set 10 | solnechnyy
# Processing Record 48 of Set 10 | yarada
# Processing Record 49 of Set 10 | ejura
# Processing Record 50 of Set 10 | dwarka
# Processing Record 1 of Set 11 | porto velho
# Processing Record 2 of Set 11 | puerto del rosario
# Processing Record 3 of Set 11 | davidson
# Processing Record 4 of Set 11 | monroe
# Processing Record 5 of Set 11 | bukachacha
# Processing Record 6 of Set 11 | padang
# Processing Record 7 of Set 11 | weihe
# Processing Record 8 of Set 11 | san vicente
# Processing Record 9 of Set 11 | madera
# Processing Record 10 of Set 11 | tulum
# Processing Record 11 of Set 11 | sao geraldo do araguaia
# Processing Record 12 of Set 11 | hammerfest
# Processing Record 13 of Set 11 | bogotol
# Processing Record 14 of Set 11 | san policarpo
# Processing Record 15 of Set 11 | kalach-na-donu
# Processing Record 16 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 17 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | vardo
# Processing Record 19 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 20 of Set 11 | road town
# Processing Record 21 of Set 11 | kyren
# Processing Record 22 of Set 11 | copiapo
# Processing Record 23 of Set 11 | tautira
# Processing Record 24 of Set 11 | miramar
# Processing Record 25 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 11 | la ronge
# Processing Record 27 of Set 11 | dvinskoy
# Processing Record 28 of Set 11 | uyuni
# Processing Record 29 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 11 | swedru
# Processing Record 31 of Set 11 | wasilla
# Processing Record 32 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 33 of Set 11 | isshiki
# City not found. Skipping...
# Processing Record 34 of Set 11 | zhanakorgan
# Processing Record 35 of Set 11 | martapura
# Processing Record 36 of Set 11 | general teran
# Processing Record 37 of Set 11 | bauchi
# Processing Record 38 of Set 11 | katsuyama
# Processing Record 39 of Set 11 | batagay
# Processing Record 40 of Set 11 | zunyi
# Processing Record 41 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 11 | gopalpur
# Processing Record 43 of Set 11 | caorle
# Processing Record 44 of Set 11 | payo
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | champerico
# Processing Record 47 of Set 11 | chivay
# Processing Record 48 of Set 11 | yumen
# Processing Record 49 of Set 11 | haines junction
# Processing Record 50 of Set 11 | alfreton
# Processing Record 1 of Set 12 | ewa beach
# Processing Record 2 of Set 12 | pizarro
# Processing Record 3 of Set 12 | prachuap khiri khan
# Processing Record 4 of Set 12 | kidal
# Processing Record 5 of Set 12 | thinadhoo
# Processing Record 6 of Set 12 | cockburn town
# Processing Record 7 of Set 12 | ocos
# Processing Record 8 of Set 12 | waingapu
# Processing Record 9 of Set 12 | innisfail
# Processing Record 10 of Set 12 | killarney
# Processing Record 11 of Set 12 | puerto escondido
# Processing Record 12 of Set 12 | sundsvall
# Processing Record 13 of Set 12 | galesong
# Processing Record 14 of Set 12 | kanungu
# Processing Record 15 of Set 12 | ucluelet
# Processing Record 16 of Set 12 | mercedes
# Processing Record 17 of Set 12 | bathsheba
# Processing Record 18 of Set 12 | bougouni
# Processing Record 19 of Set 12 | kosino
# Processing Record 20 of Set 12 | vila velha
# Processing Record 21 of Set 12 | roebourne
# Processing Record 22 of Set 12 | umba
# Processing Record 23 of Set 12 | san fernando
# Processing Record 24 of Set 12 | hoquiam
# Processing Record 25 of Set 12 | kudahuvadhoo
# Processing Record 26 of Set 12 | odweyne
# Processing Record 27 of Set 12 | mbuji-mayi
# Processing Record 28 of Set 12 | bandarbeyla
# Processing Record 29 of Set 12 | vangaindrano
# Processing Record 30 of Set 12 | garwa
# Processing Record 31 of Set 12 | eureka
# Processing Record 32 of Set 12 | zile
# Processing Record 33 of Set 12 | tukrah
# Processing Record 34 of Set 12 | shagonar
# Processing Record 35 of Set 12 | sayville
# Processing Record 36 of Set 12 | narrabri
# Processing Record 37 of Set 12 | hongjiang
# Processing Record 38 of Set 12 | maulvi bazar
# City not found. Skipping...
# Processing Record 39 of Set 12 | esperance
# Processing Record 40 of Set 12 | severnoye
# Processing Record 41 of Set 12 | kewanee
# Processing Record 42 of Set 12 | nueve de julio
# Processing Record 43 of Set 12 | lagoa
# Processing Record 44 of Set 12 | samur
# Processing Record 45 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 46 of Set 12 | batsfjord
# Processing Record 47 of Set 12 | dhanbad
# Processing Record 48 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 12 | kostino
# Processing Record 50 of Set 12 | puerto madryn
# Processing Record 1 of Set 13 | sinnamary
# Processing Record 2 of Set 13 | guerrero negro
# Processing Record 3 of Set 13 | qui nhon
# Processing Record 4 of Set 13 | da nang
# Processing Record 5 of Set 13 | itaueira
# Processing Record 6 of Set 13 | keningau
# Processing Record 7 of Set 13 | port augusta
# Processing Record 8 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 13 | rio gallegos
# Processing Record 10 of Set 13 | kopavogur
# Processing Record 11 of Set 13 | svetlyy
# Processing Record 12 of Set 13 | port-cartier
# Processing Record 13 of Set 13 | merrill
# Processing Record 14 of Set 13 | santa maria
# Processing Record 15 of Set 13 | kawalu
# Processing Record 16 of Set 13 | mount gambier
# Processing Record 17 of Set 13 | presidencia roque saenz pena
# Processing Record 18 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 13 | manaus
# Processing Record 20 of Set 13 | hanko
# Processing Record 21 of Set 13 | silopi
# Processing Record 22 of Set 13 | boende
# Processing Record 23 of Set 13 | saint-joseph
# Processing Record 24 of Set 13 | sobolevo
# Processing Record 25 of Set 13 | tartagal
# Processing Record 26 of Set 13 | bafq
# Processing Record 27 of Set 13 | sabla
# Processing Record 28 of Set 13 | rio grande
# Processing Record 29 of Set 13 | abalak
# Processing Record 30 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 13 | tessalit
# Processing Record 32 of Set 13 | torrington
# Processing Record 33 of Set 13 | malavalli
# Processing Record 34 of Set 13 | batticaloa
# Processing Record 35 of Set 13 | erhlin
# City not found. Skipping...
# Processing Record 36 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 13 | mahina
# Processing Record 38 of Set 13 | darnah
# Processing Record 39 of Set 13 | abha
# Processing Record 40 of Set 13 | koungou
# Processing Record 41 of Set 13 | homer
# Processing Record 42 of Set 13 | swan river
# Processing Record 43 of Set 13 | maldonado
# Processing Record 44 of Set 13 | santiago del estero
# Processing Record 45 of Set 13 | gudiyattam
# City not found. Skipping...
# Processing Record 46 of Set 13 | christchurch
# Processing Record 47 of Set 13 | gediz
# Processing Record 48 of Set 13 | burley
# Processing Record 49 of Set 13 | dubrovnik
# Processing Record 50 of Set 13 | buchanan
# Processing Record 1 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 14 | noumea
# Processing Record 3 of Set 14 | ous
# Processing Record 4 of Set 14 | wuzhou
# Processing Record 5 of Set 14 | dakar
# Processing Record 6 of Set 14 | saint anthony
# Processing Record 7 of Set 14 | roald
# Processing Record 8 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 14 | mbacke
# City not found. Skipping...
# Processing Record 10 of Set 14 | chumikan
# Processing Record 11 of Set 14 | sencha
# Processing Record 12 of Set 14 | vila do maio
# Processing Record 13 of Set 14 | mashhad
# Processing Record 14 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 14 | roros
# Processing Record 16 of Set 14 | whitianga
# Processing Record 17 of Set 14 | san quintin
# Processing Record 18 of Set 14 | porto novo
# Processing Record 19 of Set 14 | shingu
# Processing Record 20 of Set 14 | enterprise
# Processing Record 21 of Set 14 | sampit
# Processing Record 22 of Set 14 | guatire
# Processing Record 23 of Set 14 | samarai
# Processing Record 24 of Set 14 | tlajomulco
# Processing Record 25 of Set 14 | itaituba
# Processing Record 26 of Set 14 | zolochiv
# Processing Record 27 of Set 14 | correntina
# Processing Record 28 of Set 14 | santa rosalia
# Processing Record 29 of Set 14 | poum
# Processing Record 30 of Set 14 | majagual
# Processing Record 31 of Set 14 | new glasgow
# Processing Record 32 of Set 14 | shangqiu
# Processing Record 33 of Set 14 | caraz
# Processing Record 34 of Set 14 | praia
# Processing Record 35 of Set 14 | cowra
# Processing Record 36 of Set 14 | kulhudhuffushi
# Processing Record 37 of Set 14 | dalby
# Processing Record 38 of Set 14 | kuusamo
# Processing Record 39 of Set 14 | catamarca
# Processing Record 40 of Set 14 | palivere
# Processing Record 41 of Set 14 | ndele
# Processing Record 42 of Set 14 | nambucca heads
# Processing Record 43 of Set 14 | nyuksenitsa
# Processing Record 44 of Set 14 | dukat
# Processing Record 45 of Set 14 | mareeba
# Processing Record 46 of Set 14 | san rafael
# Processing Record 47 of Set 14 | sabha
# Processing Record 48 of Set 14 | waipawa
# Processing Record 49 of Set 14 | bokoro
# Processing Record 50 of Set 14 | marinette
# Processing Record 1 of Set 15 | nara
# Processing Record 2 of Set 15 | pombia
# Processing Record 3 of Set 15 | tarakan
# Processing Record 4 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 15 | kameshkovo
# Processing Record 6 of Set 15 | pietarsaari
# Processing Record 7 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 15 | olinda
# Processing Record 9 of Set 15 | filingue
# Processing Record 10 of Set 15 | jiuquan
# Processing Record 11 of Set 15 | manicore
# Processing Record 12 of Set 15 | eenhana
# Processing Record 13 of Set 15 | weinan
# Processing Record 14 of Set 15 | upata
# Processing Record 15 of Set 15 | debre tabor
# Processing Record 16 of Set 15 | mahibadhoo
# Processing Record 17 of Set 15 | toamasina
# Processing Record 18 of Set 15 | ginda
# Processing Record 19 of Set 15 | constitucion
# Processing Record 20 of Set 15 | farafangana
# Processing Record 21 of Set 15 | roma
# Processing Record 22 of Set 15 | san cristobal
# Processing Record 23 of Set 15 | balabac
# Processing Record 24 of Set 15 | daru
# Processing Record 25 of Set 15 | taltal
# Processing Record 26 of Set 15 | ceres
# Processing Record 27 of Set 15 | bridlington
# Processing Record 28 of Set 15 | asfi
# Processing Record 29 of Set 15 | pasuquin
# Processing Record 30 of Set 15 | sebeta
# Processing Record 31 of Set 15 | arcata
# Processing Record 32 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 15 | lesnoy
# Processing Record 34 of Set 15 | peabiru
# Processing Record 35 of Set 15 | quilali
# Processing Record 36 of Set 15 | skagen
# Processing Record 37 of Set 15 | hay river
# Processing Record 38 of Set 15 | west wendover
# Processing Record 39 of Set 15 | axim
# Processing Record 40 of Set 15 | panikihan
# Processing Record 41 of Set 15 | isla mujeres
# Processing Record 42 of Set 15 | walvis bay
# Processing Record 43 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 15 | chinsali
# Processing Record 45 of Set 15 | cessnock
# Processing Record 46 of Set 15 | hachinohe
# Processing Record 47 of Set 15 | tilichiki
# Processing Record 48 of Set 15 | nishihara
# Processing Record 49 of Set 15 | halifax
# Processing Record 50 of Set 15 | mocuba
# Processing Record 1 of Set 16 | kugulta
# Processing Record 2 of Set 16 | gravelbourg
# Processing Record 3 of Set 16 | clarence town
# Processing Record 4 of Set 16 | springbok
# Processing Record 5 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 16 | maragogi
# Processing Record 7 of Set 16 | mahajanga
# Processing Record 8 of Set 16 | koshurnikovo
# Processing Record 9 of Set 16 | moose factory
# Processing Record 10 of Set 16 | jurm
# Processing Record 11 of Set 16 | daxian
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ushuaia      AR -54.8000  -68.3000     51.80        87          75
# 1    Thompson      CA  55.7435  -97.8558    -27.40        68          75
# 2       Sines      PT  37.9562   -8.8698     55.99        81          96
# 3   Okitipupa      NG   6.5047    4.7839     77.45        95          95
# 4     Muborak      UZ  39.2553   65.1528     54.90        57         100
# 5  Butaritari      KI   3.0707  172.7902     81.32        80          32
# 6      Kodiak      US  57.7900 -152.4072     28.40        69           1
# 7     Lerwick      GB  60.1545   -1.1494     32.54        89          95
# 8      Bethel      US  41.3712  -73.4140     28.99        64          90
# 9   Tecolutla      MX  20.4833  -97.0167     72.64        80          97
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1       14.97                snow
# 2       10.00     overcast clouds
# 3        1.43     overcast clouds
# 4        8.72     overcast clouds
# 5       17.25    scattered clouds
# 6        3.44           clear sky
# 7        7.20     overcast clouds
# 8       13.80     overcast clouds
# 9        7.36     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
